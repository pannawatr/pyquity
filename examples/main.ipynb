# %%
# Add path for jupyter notebook
import sys
sys.path.append('../../pyquity')

import matplotlib
matplotlib.use('tkagg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 5
#       2 import sys
#       3 sys.path.append('../../pyquity')
# ----> 5 import matplotlib
#       6 # matplotlib.use('macosx')
#
# File ~/Documents/Works/PyQuity/.venv/lib/python3.9/site-packages/matplotlib/__init__.py:1273
#    1269     rcParams['backend_fallback'] = False
#    1272 if os.environ.get('MPLBACKEND'):
# -> 1273     rcParams['backend'] = os.environ.get('MPLBACKEND')
#    1276 def get_backend():
#    1277     """
#    1278     Return the name of the current backend.
#    1279
#    (...)
#    1282     matplotlib.use
#    1283     """
#
# File ~/Documents/Works/PyQuity/.venv/lib/python3.9/site-packages/matplotlib/__init__.py:741, in RcParams.__setitem__(self, key, val)
#     739         cval = self.validate[key](val)
#     740     except ValueError as ve:
# ...

# %%
import pyquity
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import pyquity
#
# File ~/Documents/Works/PyQuity/examples/../../pyquity/pyquity/__init__.py:1
# ----> 1 from .plot import *
#       2 from .graph import *
#       3 from .utils import *
#
# File ~/Documents/Works/PyQuity/examples/../../pyquity/pyquity/plot.py:1
# ----> 1 import osmnx as ox
#       2 import networkx as nx
#       3 import matplotlib.pyplot as plt
#
# File ~/Documents/Works/PyQuity/.venv/lib/python3.9/site-packages/osmnx/__init__.py:26
#      24 from . import graph as graph
#      25 from . import io as io
# ---> 26 from . import plot as plot
#      27 from . import projection as projection
#      28 from . import routing as routing
#
# File ~/Documents/Works/PyQuity/.venv/lib/python3.9/site-packages/osmnx/plot.py:30
# ...
